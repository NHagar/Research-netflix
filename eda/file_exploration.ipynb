# %%
import pathlib

import pandas as pd

# %%
files = list(pathlib.Path("../data").glob("*"))

# %%
by_country = pd.read_csv(files[0], sep='\t')
globe = pd.read_csv(files[1], sep='\t')

# %% [markdown]
# The by country file contains weekly top 10 data for 94 countries, across 36 weeks, for movies and TV shows.
#
# The global file contains global top 10 data across 36 weeks, with a rounded total hours viewed value for each entry. It also categorizes films and TV shows into English and non-English.
#
# The by country file is a better fit for this task, since the global lists are going to be heavily weighted by differences in population.

# %%
by_country
# Out:
#       country_name country_iso2        week category  weekly_rank  \
# 0        Argentina           AR  2022-03-06    Films            1
# 1        Argentina           AR  2022-03-06    Films            2
# 2        Argentina           AR  2022-03-06    Films            3
# 3        Argentina           AR  2022-03-06    Films            4
# 4        Argentina           AR  2022-03-06    Films            5
# ...            ...          ...         ...      ...          ...
# 67655      Vietnam           VN  2021-07-04       TV            6
# 67656      Vietnam           VN  2021-07-04       TV            7
# 67657      Vietnam           VN  2021-07-04       TV            8
# 67658      Vietnam           VN  2021-07-04       TV            9
# 67659      Vietnam           VN  2021-07-04       TV           10
#
#                               show_title                    season_title  \
# 0                         Chernobyl 1986                             NaN
# ...

# %%
globe
# Out:
#             week          category  weekly_rank  \
# 0     2022-03-06   Films (English)            1
# 1     2022-03-06   Films (English)            2
# 2     2022-03-06   Films (English)            3
# 3     2022-03-06   Films (English)            4
# 4     2022-03-06   Films (English)            5
# ...          ...               ...          ...
# 1435  2021-07-04  TV (Non-English)            6
# 1436  2021-07-04  TV (Non-English)            7
# 1437  2021-07-04  TV (Non-English)            8
# 1438  2021-07-04  TV (Non-English)            9
# 1439  2021-07-04  TV (Non-English)           10
#
#                              show_title                  season_title  \
# 0                      The Weekend Away                           NaN
# 1                       Against The Ice                           NaN
# 2                    A Madea Homecoming                           NaN
# 3     Spider-Man: Into the Spider-Verse                           NaN
# ...
